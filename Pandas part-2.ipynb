# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
##Dataframe




import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'

# %%
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame =pd.read_clipboard(  )  ##give space in the bracket so that the values and the column names would be in correct position

# %%
nfl_frame    ##0,1,2,3,4 are index
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_frame.Team
# Out:
# 0       Green Bay Packers
# 1          Dallas Cowboys
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
nfl_frame.Lost
# Out:
# 0    581
# 1    403
# 2    411
# 3    610
# 4    183
# Name: Lost, dtype: int64

# %%
nfl_frame.Won
# Out:
# 0    782
# 1    538
# 2    529
# 3    783
# 4    233
# Name: Won, dtype: int64

# %%
nfl_frame['First NFL season']      ##column name having more than one word should be in list foramt
# Out:
# 0    1921
# 1    1960
# 2    1960
# 3    1920
# 4    1996
# Name: First NFL season, dtype: int64

# %%
##getting multiple columns

DataFrame(nfl_frame,columns = ['Team', 'First NFL season' , 'Pct.'])
# Out:
#                    Team  First NFL season   Pct.
# 0     Green Bay Packers              1921  0.572
# 1        Dallas Cowboys              1960  0.571
# 2  New England Patriots              1960  0.562
# 3         Chicago Bears              1920  0.560
# 4      Baltimore Ravens              1996  0.560

# %%
DataFrame(nfl_frame,columns = ['Team', 'First NFL season' , 'Pct.','stadium'])  ##stadium column is not available but still it shows wutn NaN values in the table
# Out:
#                    Team  First NFL season   Pct.  stadium
# 0     Green Bay Packers              1921  0.572      NaN
# 1        Dallas Cowboys              1960  0.571      NaN
# 2  New England Patriots              1960  0.562      NaN
# 3         Chicago Bears              1920  0.560      NaN
# 4      Baltimore Ravens              1996  0.560      NaN

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.head() ##shows first 5 rows
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.head(3) ##shows first 3 rows
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East

# %%
nfl_frame.tail(3)  ##shows last 3 rows
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame.tail(1)   ##shows last row
# Out:
#    Rank              Team   GP  Won  Lost  Tied  Pct.  First NFL season  \
# 4     5  Baltimore Ravens  417  233   183     1  0.56              1996
#
#     Division
# 4  AFC North

# %%
nfl_frame.index[3]   ##it should show index 3 info in the output
# Out:
# 3

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_frame['stadium'] = "Levi's stadium"

# %%
nfl_frame  ## stadium values changed NaevN - Levi's stadium
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         stadium
# 0              1921  NFC North  Levi's stadium
# 1              1960   NFC East  Levi's stadium
# 2              1960   AFC East  Levi's stadium
# 3              1920  NFC North  Levi's stadium
# 4              1996  AFC North  Levi's stadium

# %%
nfl_frame['stadium'] = np.arange(5) ##5 rows

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division  stadium
# 0              1921  NFC North        0
# 1              1960   NFC East        1
# 2              1960   AFC East        2
# 3              1920  NFC North        3
# 4              1996  AFC North        4

# %%
stadiums = Series(["Levi's stadium","AT&T"],index = [4,0])

# %%
stadiums ##inserting stadium values
# Out:
# 4    Levi's stadium
# 0              AT&T
# dtype: object

# %%
nfl_frame['stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         stadium
# 0              1921  NFC North            AT&T
# 1              1960   NFC East             NaN
# 2              1960   AFC East             NaN
# 3              1920  NFC North             NaN
# 4              1996  AFC North  Levi's stadium

# %%
del nfl_frame['stadium']  ##stadium column is deleted

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
data = {'city': ['SF','CA','WA'],'population':[8300000,34566600,34879000]}

# %%
city_frame =DataFrame(data)

# %%
city_frame
# Out:
#   city  population
# 0   SF     8300000
# 1   CA    34566600
# 2   WA    34879000
